# %%
from numpy.random import seed
seed(101)

import pandas as pd
import numpy as np

import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

tf.random.set_seed(101)

import os

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import itertools
import shutil
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# dataset_dir = '../../Documents/skin-cancer-mnist-ham10000/'
# base_dir = 'base_dir'
# train_dir = os.path.join(base_dir, 'train_dir')
# val_dir = os.path.join(base_dir, 'val_dir')

# df_data = pd.read_csv(dataset_dir + '/HAM10000_metadata.csv')

# # this will tell us how many images are associated with each lesion_id
# df = df_data.groupby('lesion_id').count()

# # now we filter out lesion_id's that have only one image associated with it
# df = df[df['image_id'] == 1]
# df.reset_index(inplace=True)


# # here we identify lesion_id's that have duplicate images and those that have only
# # one image.

# def identify_duplicates(x):
#     unique_list = list(df['lesion_id'])
    
#     if x in unique_list:
#         return 'no_duplicates'
#     else:
#         return 'has_duplicates'
    
# # create a new colum that is a copy of the lesion_id column
# df_data['duplicates'] = df_data['lesion_id']
# # apply the function to this new column
# df_data['duplicates'] = df_data['duplicates'].apply(identify_duplicates)

# # now we filter out images that don't have duplicates
# df = df_data[df_data['duplicates'] == 'no_duplicates']

# # now we create a val set using df because we are sure that none of these images
# # have augmented duplicates in the train set
# y = df['dx']

# _, df_val = train_test_split(df, test_size=0.17, random_state=101, stratify=y)

# # This set will be df_data excluding all rows that are in the val set

# # This function identifies if an image is part of the train
# # or val set.
# def identify_val_rows(x):
#     # create a list of all the lesion_id's in the val set
#     val_list = list(df_val['image_id'])
    
#     if str(x) in val_list:
#         return 'val'
#     else:
#         return 'train'

# # identify train and val rows

# # create a new colum that is a copy of the image_id column
# df_data['train_or_val'] = df_data['image_id']
# # apply the function to this new column
# df_data['train_or_val'] = df_data['train_or_val'].apply(identify_val_rows)
   
# # filter out train rows
# df_train = df_data[df_data['train_or_val'] == 'train']


# print(len(df_train))
# print(len(df_val))
# Out:
# 9077
# 938

# %%
# for v2

dataset_dir = '../../Documents/skin-cancer-mnist-ham10000/'
base_dir = 'base_dir_v2'
train_dir = os.path.join(base_dir, 'train_dir')
val_dir = os.path.join(base_dir, 'val_dir')

df_data = pd.read_csv(dataset_dir + '/HAM10000_metadata.csv')


#X = df_data.drop('dx', axis=1)
y = df_data['dx']

df_train, df_val = train_test_split(df_data, test_size=0.1, random_state=101, stratify=y)

print(df_train.shape)
print(df_val.shape)
# Out:
# (9013, 7)
# (1002, 7)

# %%
train_path = base_dir + '/train_dir'
valid_path = base_dir + '/val_dir'

num_train_samples = len(df_train)
num_val_samples = len(df_val)
train_batch_size = 10
val_batch_size = 10
image_size = 224

train_steps = np.ceil(num_train_samples / train_batch_size)
val_steps = np.ceil(num_val_samples / val_batch_size)


datagen = ImageDataGenerator(
    preprocessing_function= \
    tf.keras.applications.mobilenet.preprocess_input)

train_batches = datagen.flow_from_directory(train_path,
                                            target_size=(image_size,image_size),
                                            batch_size=train_batch_size)

valid_batches = datagen.flow_from_directory(valid_path,
                                            target_size=(image_size,image_size),
                                            batch_size=val_batch_size)

# Note: shuffle=False causes the test dataset to not be shuffled
test_batches = datagen.flow_from_directory(valid_path,
                                            target_size=(image_size,image_size),
                                            batch_size=1,
                                            shuffle=False)

from tensorflow.keras.metrics import categorical_accuracy, top_k_categorical_accuracy

def top_3_accuracy(y_true, y_pred):
    return top_k_categorical_accuracy(y_true, y_pred, k=3)

def top_2_accuracy(y_true, y_pred):
    return top_k_categorical_accuracy(y_true, y_pred, k=2)

class_weights = {
    0: 1.0, # akiec
    1: 1.0, # bcc
    2: 1.0, # bkl
    3: 1.0, # df
    4: 3.0, # mel # Try to make the model more sensitive to Melanoma.
    5: 1.0, # nv
    6: 1.0, # vasc
}
# Out:
# Found 38704 images belonging to 7 classes.
# Found 1002 images belonging to 7 classes.
# Found 1002 images belonging to 7 classes.

# %%
# create a copy of a mobilenet model
mobile = tf.keras.applications.mobilenet.MobileNet()

mobile.summary()
print(type(mobile.layers))
# How many layers does MobileNet have?
print(len(mobile.layers))

# CREATE THE MODEL ARCHITECTURE

# Exclude the last 5 layers of the above model.
# This will include all layers up to and including global_average_pooling2d_1
x = mobile.layers[-6].output

# Create a new dense layer for predictions
# 7 corresponds to the number of classes
x = Dropout(0.25)(x)
predictions = Dense(7, activation='softmax')(x)

# inputs=mobile.input selects the input layer, outputs=predictions refers to the
# dense layer we created above.

model = Model(inputs=mobile.input, outputs=predictions)

# We need to choose how many layers we actually want to be trained.

# Here we are freezing the weights of all layers except the
# last 23 layers in the new model.
# The last 23 layers of the model will be trained.

for layer in model.layers[:-23]:
    layer.trainable = False
# Out:
# Model: "mobilenet_1.00_224"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 225, 225, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 112, 112, 64)      2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 112, 112, 64)      256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 112, 112, 64)      0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 113, 113, 64)      0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 56, 56, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 56, 56, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 56, 56, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 57, 57, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 28, 28, 128)       512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 28, 28, 256)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 28, 28, 256)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 29, 29, 256)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)       2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 14, 14, 256)       1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 14, 14, 512)       131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)       0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 7, 7, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 7, 7, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 7, 7, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 7, 7, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 7, 7, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 1, 1, 1024)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 1, 1024)        0
# _________________________________________________________________
# conv_preds (Conv2D)          (None, 1, 1, 1000)        1025000
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 1000)              0
# _________________________________________________________________
# act_softmax (Activation)     (None, 1000)              0
# =================================================================
# Total params: 4,253,864
# Trainable params: 4,231,976
# Non-trainable params: 21,888
# _________________________________________________________________
# <class 'list'>
# 93

# %%
model.compile(Adam(lr=0.01), loss='categorical_crossentropy', 
              metrics=[categorical_accuracy, top_2_accuracy, top_3_accuracy])

filepath = "mobilenet_model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_categorical_accuracy', verbose=1, 
                             save_best_only=True, mode='max')

reduce_lr = ReduceLROnPlateau(monitor='val_top_3_accuracy', factor=0.5, patience=2, 
                                   verbose=1, mode='max', min_lr=0.00001)
                              
                              
callbacks_list = [checkpoint, reduce_lr]

history = model.fit_generator(train_batches, steps_per_epoch=train_steps, 
                              class_weight=class_weights,
                    validation_data=valid_batches,
                    validation_steps=val_steps,
                    epochs=30, verbose=1,
                   callbacks=callbacks_list)

# %%
# Here the the last epoch will be used.

val_loss, val_cat_acc, val_top_2_acc, val_top_3_acc = \
model.evaluate_generator(test_batches, 
                        steps=len(df_val))

print('val_loss:', val_loss)
print('val_cat_acc:', val_cat_acc)
print('val_top_2_acc:', val_top_2_acc)
print('val_top_3_acc:', val_top_3_acc)

# %%
# Here the best epoch will be used.

model.load_weights('mobilenet_model.h5')

val_loss, val_cat_acc, val_top_2_acc, val_top_3_acc = \
model.evaluate_generator(test_batches, 
                        steps=len(df_val))

print('val_loss:', val_loss)
print('val_cat_acc:', val_cat_acc)
print('val_top_2_acc:', val_top_2_acc)
print('val_top_3_acc:', val_top_3_acc)

# %%
# display the loss and accuracy curves

import matplotlib.pyplot as plt

acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
train_top2_acc = history.history['top_2_accuracy']
val_top2_acc = history.history['val_top_2_accuracy']
train_top3_acc = history.history['top_3_accuracy']
val_top3_acc = history.history['val_top_3_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.figure()

plt.plot(epochs, acc, 'bo', label='Training cat acc')
plt.plot(epochs, val_acc, 'b', label='Validation cat acc')
plt.title('Training and validation cat accuracy')
plt.legend()
plt.figure()


plt.plot(epochs, train_top2_acc, 'bo', label='Training top2 acc')
plt.plot(epochs, val_top2_acc, 'b', label='Validation top2 acc')
plt.title('Training and validation top2 accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, train_top3_acc, 'bo', label='Training top3 acc')
plt.plot(epochs, val_top3_acc, 'b', label='Validation top3 acc')
plt.title('Training and validation top3 accuracy')
plt.legend()


plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-ae08c3fc3dc5> in <module>
#       3 import matplotlib.pyplot as plt
#       4
# ----> 5 acc = history.history['categorical_accuracy']
#       6 val_acc = history.history['val_categorical_accuracy']
#       7 loss = history.history['loss']
#
# NameError: name 'history' is not defined

# %%
IMG_SHAPE = (224, 224, 3)

# Create the base model from the pre-trained model MobileNet V2
mobilev2 = tf.keras.applications.MobileNetV2(input_shape=IMG_SHAPE,
                                               weights='imagenet')
mobilev2.summary()
print(len(mobilev2.layers))

x = mobilev2.layers[-2].output
predictions = Dense(7, activation='softmax')(x)
model = Model(inputs=mobilev2.input, outputs=predictions)

for layer in model.layers[:-49]:
    layer.trainable = False
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 225, 225, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 112, 112, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 112, 112, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 112, 112, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 112, 112, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 112, 112, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 112, 112, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 112, 112, 96) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 113, 113, 96) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 56, 56, 96)   864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 56, 56, 96)   384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 56, 56, 96)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 56, 56, 24)   2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 56, 56, 24)   96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 56, 56, 144)  3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 56, 56, 144)  1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 56, 56, 144)  576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 56, 56, 144)  0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 56, 56, 24)   3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 56, 56, 24)   96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 56, 56, 24)   0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 56, 56, 144)  3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 57, 57, 144)  0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 28, 28, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 28, 28, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 28, 28, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 28, 28, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 28, 28, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 28, 28, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 28, 28, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 28, 28, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 28, 28, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 28, 28, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 28, 28, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 28, 28, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 28, 28, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 28, 28, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 29, 29, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 14, 14, 192)  1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 14, 14, 192)  768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 14, 14, 192)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 14, 14, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 14, 14, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 14, 14, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 14, 14, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 14, 14, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 14, 14, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 14, 14, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 14, 14, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 14, 14, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 14, 14, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 14, 14, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 14, 14, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 14, 14, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 14, 14, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 14, 14, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 14, 14, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 14, 14, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 14, 14, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 14, 14, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 14, 14, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 14, 14, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 14, 14, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 14, 14, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 14, 14, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 14, 14, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 14, 14, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 14, 14, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 14, 14, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 14, 14, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 14, 14, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 15, 15, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 7, 7, 576)    5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 7, 7, 576)    2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)    0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 7, 7, 160)    92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 7, 7, 160)    640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 7, 7, 960)    153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 7, 7, 160)    153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 7, 7, 160)    640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 7, 7, 160)    0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 7, 7, 960)    153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 7, 7, 160)    153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 7, 7, 160)    640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 7, 7, 160)    0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 7, 7, 960)    153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 7, 7, 320)    307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 7, 7, 320)    1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 7, 7, 1280)   409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)   5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 7, 7, 1280)   0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_9 (Glo (None, 1280)         0           out_relu[0][0]
# __________________________________________________________________________________________________
# Logits (Dense)                  (None, 1000)         1281000     global_average_pooling2d_9[0][0]
# ==================================================================================================
# Total params: 3,538,984
# Trainable params: 3,504,872
# Non-trainable params: 34,112
# __________________________________________________________________________________________________
# 157

# %%
base_learning_rate = 0.0001

model.compile(Adam(lr=0.01), loss='categorical_crossentropy', 
              metrics=[categorical_accuracy, top_2_accuracy, top_3_accuracy])

filepath = "mobilenetv2_model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_categorical_accuracy', verbose=1, 
                             save_best_only=True, mode='max')

reduce_lr = ReduceLROnPlateau(monitor='val_top_3_accuracy', factor=0.5, patience=2, 
                                   verbose=1, mode='max', min_lr=0.00001)
                              
                              
callbacks_list = [checkpoint, reduce_lr]

history = model.fit_generator(train_batches, steps_per_epoch=train_steps, 
                              class_weight=class_weights,
                    validation_data=valid_batches,
                    validation_steps=val_steps,
                    epochs=30, verbose=1,
                   callbacks=callbacks_list)
# Out:
# Epoch 1/30
# 907/908 [============================>.] - ETA: 0s - loss: 1.9330 - categorical_accuracy: 0.4168 - top_2_accuracy: 0.6322 - top_3_accuracy: 0.7725
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.70851, saving model to mobilenetv2_model.h5
# 908/908 [==============================] - 177s 195ms/step - loss: 1.9320 - categorical_accuracy: 0.4171 - top_2_accuracy: 0.6323 - top_3_accuracy: 0.7726 - val_loss: 4.5288 - val_categorical_accuracy: 0.7085 - val_top_2_accuracy: 0.8138 - val_top_3_accuracy: 0.9011
# Epoch 2/30
# 907/908 [============================>.] - ETA: 0s - loss: 1.3849 - categorical_accuracy: 0.5542 - top_2_accuracy: 0.7645 - top_3_accuracy: 0.8846
# Epoch 00002: val_categorical_accuracy did not improve from 0.70851
# 908/908 [==============================] - 174s 192ms/step - loss: 1.3856 - categorical_accuracy: 0.5544 - top_2_accuracy: 0.7644 - top_3_accuracy: 0.8846 - val_loss: 2.5480 - val_categorical_accuracy: 0.5255 - val_top_2_accuracy: 0.7936 - val_top_3_accuracy: 0.9000
# Epoch 3/30
# 907/908 [============================>.] - ETA: 0s - loss: 1.2990 - categorical_accuracy: 0.5862 - top_2_accuracy: 0.7890 - top_3_accuracy: 0.9020
# Epoch 00003: val_categorical_accuracy did not improve from 0.70851
#
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
# 908/908 [==============================] - 169s 186ms/step - loss: 1.2989 - categorical_accuracy: 0.5863 - top_2_accuracy: 0.7891 - top_3_accuracy: 0.9020 - val_loss: 3.3948 - val_categorical_accuracy: 0.1830 - val_top_2_accuracy: 0.5085 - val_top_3_accuracy: 0.7362
# Epoch 4/30
# 907/908 [============================>.] - ETA: 0s - loss: 1.1204 - categorical_accuracy: 0.6439 - top_2_accuracy: 0.8272 - top_3_accuracy: 0.9241
# Epoch 00004: val_categorical_accuracy did not improve from 0.70851
# 908/908 [==============================] - 170s 187ms/step - loss: 1.1202 - categorical_accuracy: 0.6438 - top_2_accuracy: 0.8271 - top_3_accuracy: 0.9241 - val_loss: 0.8525 - val_categorical_accuracy: 0.6968 - val_top_2_accuracy: 0.8415 - val_top_3_accuracy: 0.9404
# Epoch 5/30
# 907/908 [============================>.] - ETA: 0s - loss: 1.0705 - categorical_accuracy: 0.6572 - top_2_accuracy: 0.8433 - top_3_accuracy: 0.9345
# Epoch 00005: val_categorical_accuracy did not improve from 0.70851
# 908/908 [==============================] - 172s 190ms/step - loss: 1.0709 - categorical_accuracy: 0.6570 - top_2_accuracy: 0.8429 - top_3_accuracy: 0.9345 - val_loss: 1.0615 - val_categorical_accuracy: 0.6532 - val_top_2_accuracy: 0.8181 - val_top_3_accuracy: 0.9160
# Epoch 6/30
# 907/908 [============================>.] - ETA: 0s - loss: 1.0178 - categorical_accuracy: 0.6707 - top_2_accuracy: 0.8590 - top_3_accuracy: 0.9423
# Epoch 00006: val_categorical_accuracy did not improve from 0.70851
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 908/908 [==============================] - 171s 188ms/step - loss: 1.0176 - categorical_accuracy: 0.6707 - top_2_accuracy: 0.8589 - top_3_accuracy: 0.9423 - val_loss: 2.2952 - val_categorical_accuracy: 0.3362 - val_top_2_accuracy: 0.8298 - val_top_3_accuracy: 0.9064
# Epoch 7/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.9242 - categorical_accuracy: 0.7039 - top_2_accuracy: 0.8799 - top_3_accuracy: 0.9545
# Epoch 00007: val_categorical_accuracy did not improve from 0.70851
# 908/908 [==============================] - 170s 187ms/step - loss: 0.9237 - categorical_accuracy: 0.7041 - top_2_accuracy: 0.8801 - top_3_accuracy: 0.9545 - val_loss: 0.8800 - val_categorical_accuracy: 0.6798 - val_top_2_accuracy: 0.8745 - val_top_3_accuracy: 0.9606
# Epoch 8/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.8867 - categorical_accuracy: 0.7197 - top_2_accuracy: 0.8857 - top_3_accuracy: 0.9588
# Epoch 00008: val_categorical_accuracy did not improve from 0.70851
# 908/908 [==============================] - 170s 188ms/step - loss: 0.8864 - categorical_accuracy: 0.7197 - top_2_accuracy: 0.8857 - top_3_accuracy: 0.9589 - val_loss: 1.1743 - val_categorical_accuracy: 0.6011 - val_top_2_accuracy: 0.8085 - val_top_3_accuracy: 0.9096
# Epoch 9/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.8638 - categorical_accuracy: 0.7284 - top_2_accuracy: 0.8926 - top_3_accuracy: 0.9601
# Epoch 00009: val_categorical_accuracy did not improve from 0.70851
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 908/908 [==============================] - 171s 188ms/step - loss: 0.8644 - categorical_accuracy: 0.7284 - top_2_accuracy: 0.8926 - top_3_accuracy: 0.9601 - val_loss: 1.1237 - val_categorical_accuracy: 0.6372 - val_top_2_accuracy: 0.8511 - val_top_3_accuracy: 0.9170
# Epoch 10/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.7557 - categorical_accuracy: 0.7583 - top_2_accuracy: 0.9169 - top_3_accuracy: 0.9736
# Epoch 00010: val_categorical_accuracy did not improve from 0.70851
# 908/908 [==============================] - 172s 190ms/step - loss: 0.7558 - categorical_accuracy: 0.7581 - top_2_accuracy: 0.9167 - top_3_accuracy: 0.9737 - val_loss: 2.5526 - val_categorical_accuracy: 0.2787 - val_top_2_accuracy: 0.7819 - val_top_3_accuracy: 0.8777
# Epoch 11/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.7261 - categorical_accuracy: 0.7691 - top_2_accuracy: 0.9201 - top_3_accuracy: 0.9767
# Epoch 00011: val_categorical_accuracy did not improve from 0.70851
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 908/908 [==============================] - 172s 190ms/step - loss: 0.7261 - categorical_accuracy: 0.7693 - top_2_accuracy: 0.9202 - top_3_accuracy: 0.9768 - val_loss: 1.9783 - val_categorical_accuracy: 0.3830 - val_top_2_accuracy: 0.7989 - val_top_3_accuracy: 0.9053
# Epoch 12/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.6877 - categorical_accuracy: 0.7819 - top_2_accuracy: 0.9207 - top_3_accuracy: 0.9759
# Epoch 00012: val_categorical_accuracy did not improve from 0.70851
# 908/908 [==============================] - 172s 190ms/step - loss: 0.6879 - categorical_accuracy: 0.7818 - top_2_accuracy: 0.9208 - top_3_accuracy: 0.9759 - val_loss: 0.9594 - val_categorical_accuracy: 0.6755 - val_top_2_accuracy: 0.8564 - val_top_3_accuracy: 0.9436
# Epoch 13/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.6763 - categorical_accuracy: 0.7853 - top_2_accuracy: 0.9282 - top_3_accuracy: 0.9796
# Epoch 00013: val_categorical_accuracy did not improve from 0.70851
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# 908/908 [==============================] - 172s 189ms/step - loss: 0.6759 - categorical_accuracy: 0.7853 - top_2_accuracy: 0.9282 - top_3_accuracy: 0.9796 - val_loss: 2.6281 - val_categorical_accuracy: 0.3138 - val_top_2_accuracy: 0.7638 - val_top_3_accuracy: 0.8936
# Epoch 14/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.6065 - categorical_accuracy: 0.8067 - top_2_accuracy: 0.9389 - top_3_accuracy: 0.9831
# Epoch 00014: val_categorical_accuracy did not improve from 0.70851
# 908/908 [==============================] - 172s 189ms/step - loss: 0.6062 - categorical_accuracy: 0.8068 - top_2_accuracy: 0.9390 - top_3_accuracy: 0.9831 - val_loss: 1.6778 - val_categorical_accuracy: 0.4745 - val_top_2_accuracy: 0.8277 - val_top_3_accuracy: 0.9202
# Epoch 15/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.6133 - categorical_accuracy: 0.8055 - top_2_accuracy: 0.9383 - top_3_accuracy: 0.9828
# Epoch 00015: val_categorical_accuracy did not improve from 0.70851
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# 908/908 [==============================] - 171s 189ms/step - loss: 0.6133 - categorical_accuracy: 0.8054 - top_2_accuracy: 0.9384 - top_3_accuracy: 0.9828 - val_loss: 2.2124 - val_categorical_accuracy: 0.3628 - val_top_2_accuracy: 0.8181 - val_top_3_accuracy: 0.9106
# Epoch 16/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.6016 - categorical_accuracy: 0.8067 - top_2_accuracy: 0.9411 - top_3_accuracy: 0.9845
# Epoch 00016: val_categorical_accuracy did not improve from 0.70851
# 908/908 [==============================] - 171s 188ms/step - loss: 0.6020 - categorical_accuracy: 0.8067 - top_2_accuracy: 0.9411 - top_3_accuracy: 0.9844 - val_loss: 1.9419 - val_categorical_accuracy: 0.4234 - val_top_2_accuracy: 0.8202 - val_top_3_accuracy: 0.9181
# Epoch 17/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.5932 - categorical_accuracy: 0.8179 - top_2_accuracy: 0.9424 - top_3_accuracy: 0.9832
# Epoch 00017: val_categorical_accuracy did not improve from 0.70851
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# 908/908 [==============================] - 171s 188ms/step - loss: 0.5935 - categorical_accuracy: 0.8177 - top_2_accuracy: 0.9423 - top_3_accuracy: 0.9831 - val_loss: 1.7630 - val_categorical_accuracy: 0.4532 - val_top_2_accuracy: 0.8277 - val_top_3_accuracy: 0.9160
# Epoch 18/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.5746 - categorical_accuracy: 0.8183 - top_2_accuracy: 0.9455 - top_3_accuracy: 0.9857
# Epoch 00018: val_categorical_accuracy did not improve from 0.70851
# 908/908 [==============================] - 169s 187ms/step - loss: 0.5746 - categorical_accuracy: 0.8182 - top_2_accuracy: 0.9455 - top_3_accuracy: 0.9857 - val_loss: 1.9228 - val_categorical_accuracy: 0.4191 - val_top_2_accuracy: 0.8298 - val_top_3_accuracy: 0.9213
# Epoch 19/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.5678 - categorical_accuracy: 0.8171 - top_2_accuracy: 0.9464 - top_3_accuracy: 0.9865
# Epoch 00019: val_categorical_accuracy did not improve from 0.70851
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# 908/908 [==============================] - 171s 189ms/step - loss: 0.5684 - categorical_accuracy: 0.8169 - top_2_accuracy: 0.9464 - top_3_accuracy: 0.9866 - val_loss: 1.6613 - val_categorical_accuracy: 0.4883 - val_top_2_accuracy: 0.8383 - val_top_3_accuracy: 0.9266
# Epoch 20/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.5722 - categorical_accuracy: 0.8162 - top_2_accuracy: 0.9480 - top_3_accuracy: 0.9856
# Epoch 00020: val_categorical_accuracy did not improve from 0.70851
# 908/908 [==============================] - 169s 186ms/step - loss: 0.5723 - categorical_accuracy: 0.8162 - top_2_accuracy: 0.9479 - top_3_accuracy: 0.9856 - val_loss: 1.7380 - val_categorical_accuracy: 0.4628 - val_top_2_accuracy: 0.8383 - val_top_3_accuracy: 0.9181
# Epoch 21/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.5438 - categorical_accuracy: 0.8286 - top_2_accuracy: 0.9479 - top_3_accuracy: 0.9874
# Epoch 00021: val_categorical_accuracy did not improve from 0.70851
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 1.9531249563442543e-05.
# 908/908 [==============================] - 170s 188ms/step - loss: 0.5443 - categorical_accuracy: 0.8284 - top_2_accuracy: 0.9478 - top_3_accuracy: 0.9873 - val_loss: 1.4483 - val_categorical_accuracy: 0.5436 - val_top_2_accuracy: 0.8521 - val_top_3_accuracy: 0.9170
# Epoch 22/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.5449 - categorical_accuracy: 0.8286 - top_2_accuracy: 0.9513 - top_3_accuracy: 0.9889
# Epoch 00022: val_categorical_accuracy did not improve from 0.70851
# 908/908 [==============================] - 169s 186ms/step - loss: 0.5445 - categorical_accuracy: 0.8287 - top_2_accuracy: 0.9513 - top_3_accuracy: 0.9889 - val_loss: 1.5954 - val_categorical_accuracy: 0.5064 - val_top_2_accuracy: 0.8479 - val_top_3_accuracy: 0.9223
# Epoch 23/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.5323 - categorical_accuracy: 0.8316 - top_2_accuracy: 0.9518 - top_3_accuracy: 0.9885
# Epoch 00023: val_categorical_accuracy did not improve from 0.70851
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1e-05.
# 908/908 [==============================] - 170s 187ms/step - loss: 0.5321 - categorical_accuracy: 0.8316 - top_2_accuracy: 0.9519 - top_3_accuracy: 0.9885 - val_loss: 1.6393 - val_categorical_accuracy: 0.4872 - val_top_2_accuracy: 0.8436 - val_top_3_accuracy: 0.9213
# Epoch 24/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.5359 - categorical_accuracy: 0.8295 - top_2_accuracy: 0.9491 - top_3_accuracy: 0.9871
# Epoch 00024: val_categorical_accuracy did not improve from 0.70851
# 908/908 [==============================] - 170s 187ms/step - loss: 0.5356 - categorical_accuracy: 0.8296 - top_2_accuracy: 0.9492 - top_3_accuracy: 0.9871 - val_loss: 1.6401 - val_categorical_accuracy: 0.4851 - val_top_2_accuracy: 0.8436 - val_top_3_accuracy: 0.9202
# Epoch 25/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.5541 - categorical_accuracy: 0.8294 - top_2_accuracy: 0.9523 - top_3_accuracy: 0.9878
# Epoch 00025: val_categorical_accuracy did not improve from 0.70851
# 908/908 [==============================] - 169s 186ms/step - loss: 0.5541 - categorical_accuracy: 0.8295 - top_2_accuracy: 0.9523 - top_3_accuracy: 0.9878 - val_loss: 1.6456 - val_categorical_accuracy: 0.4830 - val_top_2_accuracy: 0.8447 - val_top_3_accuracy: 0.9202
# Epoch 26/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.5772 - categorical_accuracy: 0.8206 - top_2_accuracy: 0.9445 - top_3_accuracy: 0.9861
# Epoch 00026: val_categorical_accuracy did not improve from 0.70851
# 908/908 [==============================] - 171s 188ms/step - loss: 0.5768 - categorical_accuracy: 0.8208 - top_2_accuracy: 0.9446 - top_3_accuracy: 0.9861 - val_loss: 1.7050 - val_categorical_accuracy: 0.4670 - val_top_2_accuracy: 0.8372 - val_top_3_accuracy: 0.9202
# Epoch 27/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.5599 - categorical_accuracy: 0.8211 - top_2_accuracy: 0.9501 - top_3_accuracy: 0.9872
# Epoch 00027: val_categorical_accuracy did not improve from 0.70851
# 908/908 [==============================] - 168s 185ms/step - loss: 0.5597 - categorical_accuracy: 0.8211 - top_2_accuracy: 0.9502 - top_3_accuracy: 0.9872 - val_loss: 1.7011 - val_categorical_accuracy: 0.4670 - val_top_2_accuracy: 0.8394 - val_top_3_accuracy: 0.9213
# Epoch 28/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.5532 - categorical_accuracy: 0.8234 - top_2_accuracy: 0.9495 - top_3_accuracy: 0.9882
# Epoch 00028: val_categorical_accuracy did not improve from 0.70851
# 908/908 [==============================] - 169s 186ms/step - loss: 0.5536 - categorical_accuracy: 0.8231 - top_2_accuracy: 0.9493 - top_3_accuracy: 0.9881 - val_loss: 1.7175 - val_categorical_accuracy: 0.4670 - val_top_2_accuracy: 0.8372 - val_top_3_accuracy: 0.9213
# Epoch 29/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.5428 - categorical_accuracy: 0.8327 - top_2_accuracy: 0.9548 - top_3_accuracy: 0.9878
# Epoch 00029: val_categorical_accuracy did not improve from 0.70851
# 908/908 [==============================] - 171s 188ms/step - loss: 0.5425 - categorical_accuracy: 0.8328 - top_2_accuracy: 0.9547 - top_3_accuracy: 0.9878 - val_loss: 1.7284 - val_categorical_accuracy: 0.4649 - val_top_2_accuracy: 0.8351 - val_top_3_accuracy: 0.9213
# Epoch 30/30
# 907/908 [============================>.] - ETA: 0s - loss: 0.5630 - categorical_accuracy: 0.8183 - top_2_accuracy: 0.9485 - top_3_accuracy: 0.9879
# Epoch 00030: val_categorical_accuracy did not improve from 0.70851
# 908/908 [==============================] - 169s 186ms/step - loss: 0.5627 - categorical_accuracy: 0.8183 - top_2_accuracy: 0.9486 - top_3_accuracy: 0.9879 - val_loss: 1.7544 - val_categorical_accuracy: 0.4649 - val_top_2_accuracy: 0.8362 - val_top_3_accuracy: 0.9202

# %%
from MobileNet_V3 import build_mobilenet_v3
model = build_mobilenet_v3(input_size=224, num_classes=7, model_type='large', pooling_type='avg', include_top=True)

print(model.summary())
print(len(model.layers))
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 112, 112, 16) 432         input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 112, 112, 16) 64          conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 112, 112, 16) 0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 112, 112, 16) 256         activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 112, 112, 16) 64          conv2d_69[0][0]
# __________________________________________________________________________________________________
# re_lu_24 (ReLU)                 (None, 112, 112, 16) 0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_30 (DepthwiseC (None, 112, 112, 16) 160         re_lu_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 112, 112, 16) 64          depthwise_conv2d_30[0][0]
# __________________________________________________________________________________________________
# re_lu_25 (ReLU)                 (None, 112, 112, 16) 0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 112, 112, 16) 272         re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 112, 112, 16) 64          conv2d_70[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 112, 112, 64) 1024        batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 112, 112, 64) 256         conv2d_71[0][0]
# __________________________________________________________________________________________________
# re_lu_26 (ReLU)                 (None, 112, 112, 64) 0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_31 (DepthwiseC (None, 56, 56, 64)   640         re_lu_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 56, 56, 64)   256         depthwise_conv2d_31[0][0]
# __________________________________________________________________________________________________
# re_lu_27 (ReLU)                 (None, 56, 56, 64)   0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 56, 56, 24)   1560        re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 56, 56, 24)   96          conv2d_72[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 56, 56, 72)   1728        batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 56, 56, 72)   288         conv2d_73[0][0]
# __________________________________________________________________________________________________
# re_lu_28 (ReLU)                 (None, 56, 56, 72)   0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_32 (DepthwiseC (None, 56, 56, 72)   720         re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 56, 56, 72)   288         depthwise_conv2d_32[0][0]
# __________________________________________________________________________________________________
# re_lu_29 (ReLU)                 (None, 56, 56, 72)   0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 56, 56, 24)   1752        re_lu_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 56, 56, 24)   96          conv2d_74[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 56, 56, 24)   0           batch_normalization_103[0][0]
#                                                                  batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 56, 56, 72)   1728        add_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 56, 56, 72)   288         conv2d_75[0][0]
# __________________________________________________________________________________________________
# re_lu_30 (ReLU)                 (None, 56, 56, 72)   0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_33 (DepthwiseC (None, 28, 28, 72)   1872        re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 28, 28, 72)   288         depthwise_conv2d_33[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_19 (Gl (None, 72)           0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# reshape_18 (Reshape)            (None, 1, 1, 72)     0           global_average_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# dense_33 (Dense)                (None, 1, 1, 18)     1296        reshape_18[0][0]
# __________________________________________________________________________________________________
# dense_34 (Dense)                (None, 1, 1, 72)     1296        dense_33[0][0]
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 28, 28, 72)   0           batch_normalization_105[0][0]
#                                                                  dense_34[0][0]
# __________________________________________________________________________________________________
# re_lu_31 (ReLU)                 (None, 28, 28, 72)   0           multiply_16[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 28, 28, 40)   2920        re_lu_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 28, 28, 40)   160         conv2d_76[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 28, 28, 120)  4800        batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 28, 28, 120)  480         conv2d_77[0][0]
# __________________________________________________________________________________________________
# re_lu_32 (ReLU)                 (None, 28, 28, 120)  0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_34 (DepthwiseC (None, 28, 28, 120)  3120        re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 28, 28, 120)  480         depthwise_conv2d_34[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_20 (Gl (None, 120)          0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# reshape_19 (Reshape)            (None, 1, 1, 120)    0           global_average_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# dense_35 (Dense)                (None, 1, 1, 30)     3600        reshape_19[0][0]
# __________________________________________________________________________________________________
# dense_36 (Dense)                (None, 1, 1, 120)    3600        dense_35[0][0]
# __________________________________________________________________________________________________
# multiply_17 (Multiply)          (None, 28, 28, 120)  0           batch_normalization_108[0][0]
#                                                                  dense_36[0][0]
# __________________________________________________________________________________________________
# re_lu_33 (ReLU)                 (None, 28, 28, 120)  0           multiply_17[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 28, 28, 40)   4840        re_lu_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 28, 28, 40)   160         conv2d_78[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 28, 28, 40)   0           batch_normalization_109[0][0]
#                                                                  batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 28, 28, 120)  4800        add_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 28, 28, 120)  480         conv2d_79[0][0]
# __________________________________________________________________________________________________
# re_lu_34 (ReLU)                 (None, 28, 28, 120)  0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_35 (DepthwiseC (None, 28, 28, 120)  3120        re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 28, 28, 120)  480         depthwise_conv2d_35[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_21 (Gl (None, 120)          0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# reshape_20 (Reshape)            (None, 1, 1, 120)    0           global_average_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# dense_37 (Dense)                (None, 1, 1, 30)     3600        reshape_20[0][0]
# __________________________________________________________________________________________________
# dense_38 (Dense)                (None, 1, 1, 120)    3600        dense_37[0][0]
# __________________________________________________________________________________________________
# multiply_18 (Multiply)          (None, 28, 28, 120)  0           batch_normalization_111[0][0]
#                                                                  dense_38[0][0]
# __________________________________________________________________________________________________
# re_lu_35 (ReLU)                 (None, 28, 28, 120)  0           multiply_18[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 28, 28, 40)   4840        re_lu_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 28, 28, 40)   160         conv2d_80[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 28, 28, 40)   0           batch_normalization_112[0][0]
#                                                                  add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 28, 28, 240)  9600        add_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 28, 28, 240)  960         conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 28, 28, 240)  0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_36 (DepthwiseC (None, 14, 14, 240)  2400        activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 14, 14, 240)  960         depthwise_conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 14, 14, 240)  0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 14, 14, 80)   19280       activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 14, 14, 80)   320         conv2d_82[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 14, 14, 200)  16000       batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 14, 14, 200)  800         conv2d_83[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 14, 14, 200)  0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_37 (DepthwiseC (None, 14, 14, 200)  2000        activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 14, 14, 200)  800         depthwise_conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 14, 14, 200)  0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 14, 14, 80)   16080       activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 14, 14, 80)   320         conv2d_84[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 14, 14, 80)   0           batch_normalization_118[0][0]
#                                                                  batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 14, 14, 184)  14720       add_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 14, 14, 184)  736         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 14, 14, 184)  0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_38 (DepthwiseC (None, 14, 14, 184)  1840        activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 14, 14, 184)  736         depthwise_conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 14, 14, 184)  0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 14, 14, 80)   14800       activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 14, 14, 80)   320         conv2d_86[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 14, 14, 80)   0           batch_normalization_121[0][0]
#                                                                  add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 14, 14, 184)  14720       add_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 14, 14, 184)  736         conv2d_87[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 14, 14, 184)  0           batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_39 (DepthwiseC (None, 14, 14, 184)  1840        activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 14, 14, 184)  736         depthwise_conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 14, 14, 184)  0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 14, 14, 80)   14800       activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 14, 14, 80)   320         conv2d_88[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 14, 14, 80)   0           batch_normalization_124[0][0]
#                                                                  add_20[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 14, 14, 480)  38400       add_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 14, 14, 480)  1920        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 14, 14, 480)  0           batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_40 (DepthwiseC (None, 14, 14, 480)  4800        activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 14, 14, 480)  1920        depthwise_conv2d_40[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_22 (Gl (None, 480)          0           batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# reshape_21 (Reshape)            (None, 1, 1, 480)    0           global_average_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# dense_39 (Dense)                (None, 1, 1, 120)    57600       reshape_21[0][0]
# __________________________________________________________________________________________________
# dense_40 (Dense)                (None, 1, 1, 480)    57600       dense_39[0][0]
# __________________________________________________________________________________________________
# multiply_19 (Multiply)          (None, 14, 14, 480)  0           batch_normalization_126[0][0]
#                                                                  dense_40[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 14, 14, 480)  0           multiply_19[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 14, 14, 112)  53872       activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 14, 14, 112)  448         conv2d_90[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 14, 14, 672)  75264       batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 14, 14, 672)  2688        conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 14, 14, 672)  0           batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_41 (DepthwiseC (None, 14, 14, 672)  6720        activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 14, 14, 672)  2688        depthwise_conv2d_41[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_23 (Gl (None, 672)          0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# reshape_22 (Reshape)            (None, 1, 1, 672)    0           global_average_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# dense_41 (Dense)                (None, 1, 1, 168)    112896      reshape_22[0][0]
# __________________________________________________________________________________________________
# dense_42 (Dense)                (None, 1, 1, 672)    112896      dense_41[0][0]
# __________________________________________________________________________________________________
# multiply_20 (Multiply)          (None, 14, 14, 672)  0           batch_normalization_129[0][0]
#                                                                  dense_42[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 14, 14, 672)  0           multiply_20[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 14, 14, 112)  75376       activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 14, 14, 112)  448         conv2d_92[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 14, 14, 112)  0           batch_normalization_130[0][0]
#                                                                  batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 14, 14, 672)  75264       add_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 14, 14, 672)  2688        conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 14, 14, 672)  0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_42 (DepthwiseC (None, 14, 14, 672)  17472       activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 14, 14, 672)  2688        depthwise_conv2d_42[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_24 (Gl (None, 672)          0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# reshape_23 (Reshape)            (None, 1, 1, 672)    0           global_average_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# dense_43 (Dense)                (None, 1, 1, 168)    112896      reshape_23[0][0]
# __________________________________________________________________________________________________
# dense_44 (Dense)                (None, 1, 1, 672)    112896      dense_43[0][0]
# __________________________________________________________________________________________________
# multiply_21 (Multiply)          (None, 14, 14, 672)  0           batch_normalization_132[0][0]
#                                                                  dense_44[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 14, 14, 672)  0           multiply_21[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 14, 14, 160)  107680      activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 14, 14, 160)  640         conv2d_94[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 14, 14, 672)  107520      batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 14, 14, 672)  2688        conv2d_95[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 14, 14, 672)  0           batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_43 (DepthwiseC (None, 7, 7, 672)    17472       activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 7, 7, 672)    2688        depthwise_conv2d_43[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_25 (Gl (None, 672)          0           batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# reshape_24 (Reshape)            (None, 1, 1, 672)    0           global_average_pooling2d_25[0][0]
# __________________________________________________________________________________________________
# dense_45 (Dense)                (None, 1, 1, 168)    112896      reshape_24[0][0]
# __________________________________________________________________________________________________
# dense_46 (Dense)                (None, 1, 1, 672)    112896      dense_45[0][0]
# __________________________________________________________________________________________________
# multiply_22 (Multiply)          (None, 7, 7, 672)    0           batch_normalization_135[0][0]
#                                                                  dense_46[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 7, 7, 672)    0           multiply_22[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 7, 7, 160)    107680      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_136 (BatchN (None, 7, 7, 160)    640         conv2d_96[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 7, 7, 960)    153600      batch_normalization_136[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 7, 7, 960)    3840        conv2d_97[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 7, 7, 960)    0           batch_normalization_137[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_44 (DepthwiseC (None, 7, 7, 960)    24960       activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 7, 7, 960)    3840        depthwise_conv2d_44[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_26 (Gl (None, 960)          0           batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# reshape_25 (Reshape)            (None, 1, 1, 960)    0           global_average_pooling2d_26[0][0]
# __________________________________________________________________________________________________
# dense_47 (Dense)                (None, 1, 1, 240)    230400      reshape_25[0][0]
# __________________________________________________________________________________________________
# dense_48 (Dense)                (None, 1, 1, 960)    230400      dense_47[0][0]
# __________________________________________________________________________________________________
# multiply_23 (Multiply)          (None, 7, 7, 960)    0           batch_normalization_138[0][0]
#                                                                  dense_48[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 7, 7, 960)    0           multiply_23[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 7, 7, 160)    153760      activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 7, 7, 160)    640         conv2d_98[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 7, 7, 160)    0           batch_normalization_139[0][0]
#                                                                  batch_normalization_136[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 7, 7, 960)    1383360     add_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_140 (BatchN (None, 7, 7, 960)    3840        conv2d_99[0][0]
# __________________________________________________________________________________________________
# output_map (Activation)         (None, 7, 7, 960)    0           batch_normalization_140[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_27 (Gl (None, 960)          0           output_map[0][0]
# __________________________________________________________________________________________________
# reshape_26 (Reshape)            (None, 1, 1, 960)    0           global_average_pooling2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 1, 1, 1280)   1230080     reshape_26[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 1, 1, 7)      8967        conv2d_100[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 7)            0           conv2d_101[0][0]
# __________________________________________________________________________________________________
# softmax_2 (Softmax)             (None, 7)            0           flatten_2[0][0]
# ==================================================================================================
# Total params: 5,127,839
# Trainable params: 5,104,559
# Non-trainable params: 23,280
# __________________________________________________________________________________________________
# None
# 181

# %%
base_learning_rate = 0.0001

model.compile(Adam(lr=0.01), loss='categorical_crossentropy', 
              metrics=[categorical_accuracy, top_2_accuracy, top_3_accuracy])

filepath = "mobilenetv3_model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_categorical_accuracy', verbose=1, 
                             save_best_only=True, mode='max')

# reduce_lr = ReduceLROnPlateau(monitor='val_top_3_accuracy', factor=0.5, patience=2, 
#                                    verbose=1, mode='max', min_lr=0.00001)

callbacks_list = [checkpoint]
history = model.fit_generator(train_batches, steps_per_epoch=train_steps, 
                              class_weight=class_weights,
                    validation_data=valid_batches,
                    validation_steps=val_steps,
                    epochs=30, verbose=1,
                   callbacks=callbacks_list)
# Out:
# Epoch 1/30
# 907/908 [============================>.] - ETA: 0s - loss: 18.6245 - categorical_accuracy: 0.1240 - top_2_accuracy: 0.9774 - top_3_accuracy: 0.9863
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.01064, saving model to mobilenetv3_model.h5
# 908/908 [==============================] - 294s 324ms/step - loss: 18.6235 - categorical_accuracy: 0.1240 - top_2_accuracy: 0.9774 - top_3_accuracy: 0.9863 - val_loss: 15.9466 - val_categorical_accuracy: 0.0106 - val_top_2_accuracy: 0.9872 - val_top_3_accuracy: 0.9894
# Epoch 2/30
# 907/908 [============================>.] - ETA: 0s - loss: 18.9190 - categorical_accuracy: 0.1213 - top_2_accuracy: 0.9927 - top_3_accuracy: 0.9951
# Epoch 00002: val_categorical_accuracy improved from 0.01064 to 0.01596, saving model to mobilenetv3_model.h5
# 908/908 [==============================] - 294s 324ms/step - loss: 18.9159 - categorical_accuracy: 0.1214 - top_2_accuracy: 0.9927 - top_3_accuracy: 0.9952 - val_loss: 15.8609 - val_categorical_accuracy: 0.0160 - val_top_2_accuracy: 1.0000 - val_top_3_accuracy: 1.0000
# Epoch 3/30
# 907/908 [============================>.] - ETA: 0s - loss: 18.6701 - categorical_accuracy: 0.1284 - top_2_accuracy: 0.9982 - top_3_accuracy: 0.9998
# Epoch 00003: val_categorical_accuracy improved from 0.01596 to 0.01702, saving model to mobilenetv3_model.h5
# 908/908 [==============================] - 293s 322ms/step - loss: 18.6637 - categorical_accuracy: 0.1285 - top_2_accuracy: 0.9982 - top_3_accuracy: 0.9998 - val_loss: 15.8437 - val_categorical_accuracy: 0.0170 - val_top_2_accuracy: 0.9968 - val_top_3_accuracy: 0.9979
# Epoch 4/30
# 907/908 [============================>.] - ETA: 0s - loss: 18.6798 - categorical_accuracy: 0.1365 - top_2_accuracy: 0.9989 - top_3_accuracy: 1.0000
# Epoch 00004: val_categorical_accuracy did not improve from 0.01702
# 908/908 [==============================] - 290s 320ms/step - loss: 18.6805 - categorical_accuracy: 0.1363 - top_2_accuracy: 0.9989 - top_3_accuracy: 1.0000 - val_loss: 15.9123 - val_categorical_accuracy: 0.0128 - val_top_2_accuracy: 1.0000 - val_top_3_accuracy: 1.0000
# Epoch 5/30
# 907/908 [============================>.] - ETA: 0s - loss: 18.4215 - categorical_accuracy: 0.1467 - top_2_accuracy: 0.9974 - top_3_accuracy: 0.9998
# Epoch 00005: val_categorical_accuracy improved from 0.01702 to 0.02766, saving model to mobilenetv3_model.h5
# 908/908 [==============================] - 293s 322ms/step - loss: 18.4208 - categorical_accuracy: 0.1467 - top_2_accuracy: 0.9974 - top_3_accuracy: 0.9998 - val_loss: 15.6723 - val_categorical_accuracy: 0.0277 - val_top_2_accuracy: 0.9957 - val_top_3_accuracy: 0.9989
# Epoch 6/30
# 907/908 [============================>.] - ETA: 0s - loss: 18.1671 - categorical_accuracy: 0.1289 - top_2_accuracy: 0.9931 - top_3_accuracy: 0.9993
# Epoch 00006: val_categorical_accuracy did not improve from 0.02766
# 908/908 [==============================] - 293s 323ms/step - loss: 18.1666 - categorical_accuracy: 0.1291 - top_2_accuracy: 0.9931 - top_3_accuracy: 0.9993 - val_loss: 15.6894 - val_categorical_accuracy: 0.0266 - val_top_2_accuracy: 0.9926 - val_top_3_accuracy: 1.0000
# Epoch 7/30
# 907/908 [============================>.] - ETA: 0s - loss: 17.3790 - categorical_accuracy: 0.1340 - top_2_accuracy: 0.9966 - top_3_accuracy: 1.0000
# Epoch 00007: val_categorical_accuracy improved from 0.02766 to 0.03511, saving model to mobilenetv3_model.h5
# 908/908 [==============================] - 292s 322ms/step - loss: 17.3741 - categorical_accuracy: 0.1343 - top_2_accuracy: 0.9966 - top_3_accuracy: 1.0000 - val_loss: 15.5522 - val_categorical_accuracy: 0.0351 - val_top_2_accuracy: 1.0000 - val_top_3_accuracy: 1.0000
# Epoch 8/30
# 907/908 [============================>.] - ETA: 0s - loss: 17.6351 - categorical_accuracy: 0.1432 - top_2_accuracy: 0.9994 - top_3_accuracy: 0.9999
# Epoch 00008: val_categorical_accuracy did not improve from 0.03511
# 908/908 [==============================] - 291s 320ms/step - loss: 17.6264 - categorical_accuracy: 0.1435 - top_2_accuracy: 0.9994 - top_3_accuracy: 0.9999 - val_loss: 15.6037 - val_categorical_accuracy: 0.0319 - val_top_2_accuracy: 1.0000 - val_top_3_accuracy: 1.0000
# Epoch 9/30
# 907/908 [============================>.] - ETA: 0s - loss: 17.6446 - categorical_accuracy: 0.1463 - top_2_accuracy: 0.9992 - top_3_accuracy: 1.0000
# Epoch 00009: val_categorical_accuracy did not improve from 0.03511
# 908/908 [==============================] - 292s 321ms/step - loss: 17.6394 - categorical_accuracy: 0.1464 - top_2_accuracy: 0.9992 - top_3_accuracy: 1.0000 - val_loss: 15.5694 - val_categorical_accuracy: 0.0340 - val_top_2_accuracy: 0.9989 - val_top_3_accuracy: 1.0000
# Epoch 10/30
# 907/908 [============================>.] - ETA: 0s - loss: 17.8881 - categorical_accuracy: 0.1383 - top_2_accuracy: 0.9994 - top_3_accuracy: 1.0000
# Epoch 00010: val_categorical_accuracy did not improve from 0.03511
# 908/908 [==============================] - 292s 321ms/step - loss: 17.8897 - categorical_accuracy: 0.1381 - top_2_accuracy: 0.9994 - top_3_accuracy: 1.0000 - val_loss: 15.6723 - val_categorical_accuracy: 0.0277 - val_top_2_accuracy: 1.0000 - val_top_3_accuracy: 1.0000
# Epoch 11/30
# 907/908 [============================>.] - ETA: 0s - loss: 18.1475 - categorical_accuracy: 0.1449 - top_2_accuracy: 0.9998 - top_3_accuracy: 1.0000
# Epoch 00011: val_categorical_accuracy did not improve from 0.03511
# 908/908 [==============================] - 293s 322ms/step - loss: 18.1417 - categorical_accuracy: 0.1449 - top_2_accuracy: 0.9998 - top_3_accuracy: 1.0000 - val_loss: 15.6380 - val_categorical_accuracy: 0.0298 - val_top_2_accuracy: 1.0000 - val_top_3_accuracy: 1.0000
# Epoch 12/30
# 907/908 [============================>.] - ETA: 0s - loss: 18.2844 - categorical_accuracy: 0.1419 - top_2_accuracy: 0.9998 - top_3_accuracy: 1.0000
# Epoch 00012: val_categorical_accuracy did not improve from 0.03511
# 908/908 [==============================] - 293s 323ms/step - loss: 18.2855 - categorical_accuracy: 0.1417 - top_2_accuracy: 0.9998 - top_3_accuracy: 1.0000 - val_loss: 15.6551 - val_categorical_accuracy: 0.0287 - val_top_2_accuracy: 0.9989 - val_top_3_accuracy: 1.0000
# Epoch 13/30
# 907/908 [============================>.] - ETA: 0s - loss: 18.1783 - categorical_accuracy: 0.1456 - top_2_accuracy: 0.9998 - top_3_accuracy: 1.0000
# Epoch 00013: val_categorical_accuracy did not improve from 0.03511
# 908/908 [==============================] - 294s 324ms/step - loss: 18.1778 - categorical_accuracy: 0.1456 - top_2_accuracy: 0.9998 - top_3_accuracy: 1.0000 - val_loss: 15.5865 - val_categorical_accuracy: 0.0330 - val_top_2_accuracy: 1.0000 - val_top_3_accuracy: 1.0000
# Epoch 14/30
# 907/908 [============================>.] - ETA: 0s - loss: 18.1866 - categorical_accuracy: 0.1385 - top_2_accuracy: 0.9997 - top_3_accuracy: 1.0000
# Epoch 00014: val_categorical_accuracy did not improve from 0.03511
# 908/908 [==============================] - 291s 321ms/step - loss: 18.1843 - categorical_accuracy: 0.1385 - top_2_accuracy: 0.9997 - top_3_accuracy: 1.0000 - val_loss: 15.6037 - val_categorical_accuracy: 0.0319 - val_top_2_accuracy: 1.0000 - val_top_3_accuracy: 1.0000
# Epoch 15/30
# 907/908 [============================>.] - ETA: 0s - loss: 18.0687 - categorical_accuracy: 0.1496 - top_2_accuracy: 0.9998 - top_3_accuracy: 1.0000
# Epoch 00015: val_categorical_accuracy did not improve from 0.03511
# 908/908 [==============================] - 293s 323ms/step - loss: 18.0701 - categorical_accuracy: 0.1497 - top_2_accuracy: 0.9998 - top_3_accuracy: 1.0000 - val_loss: 15.6380 - val_categorical_accuracy: 0.0298 - val_top_2_accuracy: 1.0000 - val_top_3_accuracy: 1.0000
# Epoch 16/30
# 907/908 [============================>.] - ETA: 0s - loss: 18.1155 - categorical_accuracy: 0.1440 - top_2_accuracy: 0.9998 - top_3_accuracy: 1.0000
# Epoch 00016: val_categorical_accuracy did not improve from 0.03511
# 908/908 [==============================] - 292s 321ms/step - loss: 18.1133 - categorical_accuracy: 0.1441 - top_2_accuracy: 0.9998 - top_3_accuracy: 1.0000 - val_loss: 15.6208 - val_categorical_accuracy: 0.0309 - val_top_2_accuracy: 1.0000 - val_top_3_accuracy: 1.0000
# Epoch 17/30
# 907/908 [============================>.] - ETA: 0s - loss: 18.3057 - categorical_accuracy: 0.1381 - top_2_accuracy: 0.9998 - top_3_accuracy: 1.0000
# Epoch 00017: val_categorical_accuracy did not improve from 0.03511
# 908/908 [==============================] - 292s 321ms/step - loss: 18.3068 - categorical_accuracy: 0.1382 - top_2_accuracy: 0.9998 - top_3_accuracy: 1.0000 - val_loss: 15.6208 - val_categorical_accuracy: 0.0309 - val_top_2_accuracy: 1.0000 - val_top_3_accuracy: 1.0000
# Epoch 18/30
# 907/908 [============================>.] - ETA: 0s - loss: 18.0729 - categorical_accuracy: 0.1449 - top_2_accuracy: 0.9998 - top_3_accuracy: 1.0000
# Epoch 00018: val_categorical_accuracy did not improve from 0.03511
# 908/908 [==============================] - 291s 320ms/step - loss: 18.0743 - categorical_accuracy: 0.1449 - top_2_accuracy: 0.9998 - top_3_accuracy: 1.0000 - val_loss: 15.6208 - val_categorical_accuracy: 0.0309 - val_top_2_accuracy: 1.0000 - val_top_3_accuracy: 1.0000
# Epoch 19/30
# 907/908 [============================>.] - ETA: 0s - loss: 18.1191 - categorical_accuracy: 0.1422 - top_2_accuracy: 0.9997 - top_3_accuracy: 1.0000
# Epoch 00019: val_categorical_accuracy did not improve from 0.03511
# 908/908 [==============================] - 290s 319ms/step - loss: 18.1222 - categorical_accuracy: 0.1422 - top_2_accuracy: 0.9997 - top_3_accuracy: 1.0000 - val_loss: 15.6037 - val_categorical_accuracy: 0.0319 - val_top_2_accuracy: 1.0000 - val_top_3_accuracy: 1.0000
# Epoch 20/30
# 907/908 [============================>.] - ETA: 0s - loss: 18.2399 - categorical_accuracy: 0.1389 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000
# Epoch 00020: val_categorical_accuracy did not improve from 0.03511
# 908/908 [==============================] - 293s 322ms/step - loss: 18.2394 - categorical_accuracy: 0.1389 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000 - val_loss: 15.6208 - val_categorical_accuracy: 0.0309 - val_top_2_accuracy: 1.0000 - val_top_3_accuracy: 1.0000
# Epoch 21/30
# 907/908 [============================>.] - ETA: 0s - loss: 18.2370 - categorical_accuracy: 0.1431 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000
# Epoch 00021: val_categorical_accuracy did not improve from 0.03511
# 908/908 [==============================] - 293s 322ms/step - loss: 18.2417 - categorical_accuracy: 0.1430 - top_2_accuracy: 1.0000 - top_3_accuracy: 1.0000 - val_loss: 15.6037 - val_categorical_accuracy: 0.0319 - val_top_2_accuracy: 0.9989 - val_top_3_accuracy: 1.0000
# Epoch 22/30
# 907/908 [============================>.] - ETA: 0s - loss: 18.2239 - categorical_accuracy: 0.1410 - top_2_accuracy: 0.9998 - top_3_accuracy: 1.0000
# Epoch 00022: val_categorical_accuracy did not improve from 0.03511
# 908/908 [==============================] - 293s 322ms/step - loss: 18.2252 - categorical_accuracy: 0.1411 - top_2_accuracy: 0.9998 - top_3_accuracy: 1.0000 - val_loss: 15.6208 - val_categorical_accuracy: 0.0309 - val_top_2_accuracy: 1.0000 - val_top_3_accuracy: 1.0000
# Epoch 23/30
# 907/908 [============================>.] - ETA: 0s - loss: 18.1635 - categorical_accuracy: 0.1454 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000
# Epoch 00023: val_categorical_accuracy did not improve from 0.03511
# 908/908 [==============================] - 291s 321ms/step - loss: 18.1595 - categorical_accuracy: 0.1454 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000 - val_loss: 15.6208 - val_categorical_accuracy: 0.0309 - val_top_2_accuracy: 1.0000 - val_top_3_accuracy: 1.0000
# Epoch 24/30
# 907/908 [============================>.] - ETA: 0s - loss: 18.3003 - categorical_accuracy: 0.1411 - top_2_accuracy: 0.9997 - top_3_accuracy: 1.0000
# Epoch 00024: val_categorical_accuracy did not improve from 0.03511
# 908/908 [==============================] - 290s 320ms/step - loss: 18.3050 - categorical_accuracy: 0.1412 - top_2_accuracy: 0.9997 - top_3_accuracy: 1.0000 - val_loss: 15.6208 - val_categorical_accuracy: 0.0309 - val_top_2_accuracy: 0.9989 - val_top_3_accuracy: 1.0000
# Epoch 25/30
# 907/908 [============================>.] - ETA: 0s - loss: 18.2447 - categorical_accuracy: 0.1366 - top_2_accuracy: 0.9997 - top_3_accuracy: 1.0000
# Epoch 00025: val_categorical_accuracy did not improve from 0.03511
# 908/908 [==============================] - 293s 323ms/step - loss: 18.2423 - categorical_accuracy: 0.1367 - top_2_accuracy: 0.9997 - top_3_accuracy: 1.0000 - val_loss: 15.6037 - val_categorical_accuracy: 0.0319 - val_top_2_accuracy: 1.0000 - val_top_3_accuracy: 1.0000
# Epoch 26/30
# 907/908 [============================>.] - ETA: 0s - loss: 17.9929 - categorical_accuracy: 0.1461 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000
# Epoch 00026: val_categorical_accuracy did not improve from 0.03511
# 908/908 [==============================] - 292s 321ms/step - loss: 17.9979 - categorical_accuracy: 0.1461 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000 - val_loss: 15.6208 - val_categorical_accuracy: 0.0309 - val_top_2_accuracy: 1.0000 - val_top_3_accuracy: 1.0000
# Epoch 27/30
# 907/908 [============================>.] - ETA: 0s - loss: 18.5598 - categorical_accuracy: 0.1341 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000
# Epoch 00027: val_categorical_accuracy did not improve from 0.03511
# 908/908 [==============================] - 292s 322ms/step - loss: 18.5589 - categorical_accuracy: 0.1340 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000 - val_loss: 15.5865 - val_categorical_accuracy: 0.0330 - val_top_2_accuracy: 1.0000 - val_top_3_accuracy: 1.0000
# Epoch 28/30
# 907/908 [============================>.] - ETA: 0s - loss: 18.1440 - categorical_accuracy: 0.1400 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000
# Epoch 00028: val_categorical_accuracy did not improve from 0.03511
# 908/908 [==============================] - 289s 318ms/step - loss: 18.1471 - categorical_accuracy: 0.1400 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000 - val_loss: 15.6380 - val_categorical_accuracy: 0.0298 - val_top_2_accuracy: 1.0000 - val_top_3_accuracy: 1.0000
# Epoch 29/30
# 907/908 [============================>.] - ETA: 0s - loss: 18.2660 - categorical_accuracy: 0.1391 - top_2_accuracy: 0.9998 - top_3_accuracy: 1.0000
# Epoch 00029: val_categorical_accuracy did not improve from 0.03511
# 908/908 [==============================] - 292s 322ms/step - loss: 18.2672 - categorical_accuracy: 0.1392 - top_2_accuracy: 0.9998 - top_3_accuracy: 1.0000 - val_loss: 15.6037 - val_categorical_accuracy: 0.0319 - val_top_2_accuracy: 1.0000 - val_top_3_accuracy: 1.0000
# Epoch 30/30
# 907/908 [============================>.] - ETA: 0s - loss: 18.1742 - categorical_accuracy: 0.1439 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000
# Epoch 00030: val_categorical_accuracy did not improve from 0.03511
# 908/908 [==============================] - 292s 322ms/step - loss: 18.1826 - categorical_accuracy: 0.1437 - top_2_accuracy: 0.9999 - top_3_accuracy: 1.0000 - val_loss: 15.6037 - val_categorical_accuracy: 0.0319 - val_top_2_accuracy: 1.0000 - val_top_3_accuracy: 1.0000
